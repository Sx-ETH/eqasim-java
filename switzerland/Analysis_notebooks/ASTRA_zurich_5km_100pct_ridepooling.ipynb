# %%
import pandas as pd
import os
from tqdm import tqdm
import geopandas as gpd
import matplotlib.pyplot as plt
import importlib
# Out:
# /cluster/apps/nss/gcc-6.3.0/python/3.8.5/x86_64/lib64/python3.8/site-packages/pyproj/__init__.py:78: UserWarning: Valid PROJ data directory not found. Either set the path using the environmental variable PROJ_LIB or with `pyproj.datadir.set_data_dir`.
#   warnings.warn(str(err))

# %%
import ASTRA_plots_utils

# %%
importlib.reload(ASTRA_plots_utils)
# Out:
# <module 'ASTRA_plots_utils' from '/cluster/home/mfrancesc/IVT/eqasim-java/switzerland/Analysis_notebooks/ASTRA_plots_utils.py'>

# %%
path = '/cluster/scratch/mfrancesc/IVT/SA_scenario/zurich/astra_5km_100pct_copy/cost_covering'

# %%
outputs = {}
fleet_sizes = [8000, 10000, 12000, 14000, 16000, 18000]
last_iters = [95, 86, 95, 99, 91, 93]
for f,l in zip(fleet_sizes, last_iters):
    outputs[f] = ASTRA_plots_utils.read_output(os.path.join(path, 'fleet_' + str(f)), last_iter=l)
# Out:
# ...
# 100%|██████████| 94/94 [02:54<00:00,  1.85s/it]

# %%
outputs.keys()
# Out:
# dict_keys([8000, 10000, 12000, 14000, 16000, 18000])

# %%
#import copy
#last_iter = 100
#for k in outputs.keys():
#    aux = outputs[k]
#    print(k)
#    for d in aux.keys():
#        if isinstance(aux[d], list):
#            print(d)
#            l = len(aux[d])
#            for _ in range(l, last_iter+1):
#                aux[d].append(copy.deepcopy(aux[d][l-1]))

# %%
# all in last iteration
ASTRA_plots_utils.plot_amod_stats(outputs, fleet_sizes, -1, False)

# %%
# all in iteration 86 (last common)
ASTRA_plots_utils.plot_amod_stats(outputs, fleet_sizes, 86, False)

# %%
ASTRA_plots_utils.plot_vehicles_stats(outputs, fleet_sizes, -1)

# %%
ASTRA_plots_utils.plot_vehicles_stats(outputs, fleet_sizes, 86)

# %%
ASTRA_plots_utils.plot_waiting_time_over_day(outputs, fleet_sizes, -1)

# %%
ASTRA_plots_utils.plot_waiting_time_over_day(outputs, fleet_sizes, 86)

# %%
ASTRA_plots_utils.plot_distance_distribution(outputs, fleet_sizes, -1)

# %%
ASTRA_plots_utils.plot_distance_distribution(outputs, fleet_sizes, 86)

# %%
ASTRA_plots_utils.plot_convergence(outputs, [8000, 10000, 12000 , 14000], 25)

# %%
ASTRA_plots_utils.plot_convergence(outputs, fleet_sizes, 25)

# %%
ASTRA_plots_utils.plot_occupancy_drt(outputs[14000]['occupancy'][95])

# %%
ASTRA_plots_utils.plot_occupancy_drt(outputs[12000]['occupancy'][-1])

# %%
ASTRA_plots_utils.plot_occupancy_drt(outputs[14000]['occupancy'][95], add_stay_relocate=True)

# %%
ASTRA_plots_utils.plot_occupancy_drt(outputs[14000]['occupancy'][95], add_stay_relocate=True, start_time=6)
