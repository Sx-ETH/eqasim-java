# %%
import pandas as pd
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', 500)
import seaborn as sns
import numpy as np

# %%
import importlib
import plotting_utils
import utils
import euler_utils
import predictions_evaluations
importlib.reload(plotting_utils)
importlib.reload(utils)
importlib.reload(euler_utils)
importlib.reload(predictions_evaluations)
# Out:
# /cluster/apps/nss/gcc-6.3.0/python/3.8.5/x86_64/lib64/python3.8/site-packages/pyproj/__init__.py:78: UserWarning: Valid PROJ data directory not found. Either set the path using the environmental variable PROJ_LIB or with `pyproj.datadir.set_data_dir`.
#   warnings.warn(str(err))
# <module 'predictions_evaluations' from '/cluster/home/mfrancesc/IVT/eqasim-java/switzerland/Analysis_notebooks/predictions_evaluations.py'>

# %%
scratch_folder = '/cluster/scratch/mfrancesc/IVT/SA_scenario/'

# %%
data_global = euler_utils.read_output(scratch_folder + 'global_average', last_iter=50)
# Out:
# 100%|██████████| 51/51 [00:29<00:00,  1.73it/s]

# %%
display(plotting_utils.get_stats_table(data_global['drt_trips_stats'][50]))
# Out:
#                                                          Value
# Number of rides                                  168007.000000
# Wait time (min)                   Mean                9.547336
#                                   Median              6.066667
#                                   Std                12.042291
#                                   75-percentile      12.433333
#                                   99-percentile      56.014667
#                                   Max               271.283333
# Travel time (min)                 Mean               12.982519
#                                   Median              7.483333
#                                   Std                16.026758
#                                   75-percentile      16.033333
#                                   99-percentile      79.250000
#                                   Max               282.833333
# Mean direct distance (km)                             2.583084
# ...

# %%
data_zonal_square = euler_utils.read_output(scratch_folder + 'zonal_square', last_iter=50)
data_zonal_hex = euler_utils.read_output(scratch_folder + 'zonal_hex', last_iter=50)
# Out:
# ...
# 100%|██████████| 51/51 [00:33<00:00,  1.54it/s]

# %%
display(plotting_utils.get_stats_table(data_zonal_square['drt_trips_stats'][50]))
display(plotting_utils.get_stats_table(data_zonal_hex['drt_trips_stats'][50]))
# Out:
#                                                          Value
# Number of rides                                  196129.000000
# Wait time (min)                   Mean                7.147927
#                                   Median              5.766667
#                                   Std                 6.249911
#                                   75-percentile      10.233333
#                                   99-percentile      27.145333
#                                   Max               131.133333
# Travel time (min)                 Mean               12.293716
#                                   Median              7.400000
#                                   Std                14.093841
#                                   75-percentile      15.433333
#                                   99-percentile      70.250000
#                                   Max               212.083333
# Mean direct distance (km)                             2.612448
# ...

# %%
data_dynamic_FD = euler_utils.read_output(scratch_folder + 'dynamic_noDecay/dynamic_FD', last_iter=50)
# Out:
# 100%|██████████| 51/51 [00:34<00:00,  1.48it/s]

# %%
display(plotting_utils.get_stats_table(data_dynamic_FD['drt_trips_stats'][50]))
# Out:
#                                                          Value
# Number of rides                                  197343.000000
# Wait time (min)                   Mean                7.586155
#                                   Median              6.016667
#                                   Std                 7.338537
#                                   75-percentile      10.583333
#                                   99-percentile      32.050000
#                                   Max               158.266667
# Travel time (min)                 Mean               12.508798
#                                   Median              7.416667
#                                   Std                15.137956
#                                   75-percentile      15.500000
#                                   99-percentile      72.283333
#                                   Max               400.366667
# Mean direct distance (km)                             2.639733
# ...

# %%
data_dynamic_CN_k500 = euler_utils.read_output(scratch_folder + 'dynamic_noDecay/dynamic_CN_k500', last_iter=50)
data_dynamic_CN_k1000 = euler_utils.read_output(scratch_folder + 'dynamic_noDecay/dynamic_CN_k1000', last_iter=50)
data_dynamic_CN_k2000 = euler_utils.read_output(scratch_folder + 'dynamic_noDecay/dynamic_CN_k2000', last_iter=50)
# Out:
# ...
# 100%|██████████| 51/51 [00:31<00:00,  1.63it/s]

# %%
display(plotting_utils.get_stats_table(data_dynamic_CN_k500['drt_trips_stats'][50]))
display(plotting_utils.get_stats_table(data_dynamic_CN_k1000['drt_trips_stats'][50]))
display(plotting_utils.get_stats_table(data_dynamic_CN_k2000['drt_trips_stats'][50]))
# Out:
#                                                          Value
# Number of rides                                  188003.000000
# Wait time (min)                   Mean                6.912935
#                                   Median              5.350000
#                                   Std                 6.816405
#                                   75-percentile       9.416667
#                                   99-percentile      30.233000
#                                   Max               211.483333
# Travel time (min)                 Mean               12.498070
#                                   Median              7.400000
#                                   Std                15.026186
#                                   75-percentile      15.450000
#                                   99-percentile      73.650000
#                                   Max               270.500000
# Mean direct distance (km)                             2.621206
# ...

# %%
data_dynamic_PN_km500 = euler_utils.read_output(scratch_folder + 'dynamic_noDecay/dynamic_PN_km500', last_iter=50)
data_dynamic_PN_km1000 = euler_utils.read_output(scratch_folder + 'dynamic_noDecay/dynamic_PN_km1000', last_iter=50)
data_dynamic_PN_km2000 = euler_utils.read_output(scratch_folder + 'dynamic_noDecay/dynamic_PN_km2000', last_iter=50)
# Out:
# ...
# 100%|██████████| 51/51 [00:34<00:00,  1.49it/s]

# %%
display(plotting_utils.get_stats_table(data_dynamic_PN_km500['drt_trips_stats'][50]))
display(plotting_utils.get_stats_table(data_dynamic_PN_km1000['drt_trips_stats'][50]))
display(plotting_utils.get_stats_table(data_dynamic_PN_km2000['drt_trips_stats'][50]))
# Out:
#                                                          Value
# Number of rides                                  189001.000000
# Wait time (min)                   Mean                7.151347
#                                   Median              5.716667
#                                   Std                 7.518596
#                                   75-percentile       9.933333
#                                   99-percentile      30.716667
#                                   Max               334.583333
# Travel time (min)                 Mean               12.337537
#                                   Median              7.383333
#                                   Std                14.209454
#                                   75-percentile      15.466667
#                                   99-percentile      68.666667
#                                   Max               224.816667
# Mean direct distance (km)                             2.627523
# ...

# %%
print("Global")
display(plotting_utils.show_stopwatch(scratch_folder + 'global_average'))
print("Zonal square")
display(plotting_utils.show_stopwatch(scratch_folder + 'zonal_hex'))
print("Zonal hex")
display(plotting_utils.show_stopwatch(scratch_folder + 'zonal_square'))
print("Dynamic FD")
display(plotting_utils.show_stopwatch(scratch_folder + 'dynamic_noDecay/dynamic_FD'))
print("Dynamic CN 500")
display(plotting_utils.show_stopwatch(scratch_folder + 'dynamic_noDecay/dynamic_CN_k500'))
print("Dynamic CN 1000")
display(plotting_utils.show_stopwatch(scratch_folder + 'dynamic_noDecay/dynamic_CN_k1000'))
print("Dynamic CN 2000")
display(plotting_utils.show_stopwatch(scratch_folder + 'dynamic_noDecay/dynamic_CN_k2000'))
print("Dynamic PN 500")
display(plotting_utils.show_stopwatch(scratch_folder + 'dynamic_noDecay/dynamic_PN_km500'))
print("Dynamic PN 1000")
display(plotting_utils.show_stopwatch(scratch_folder + 'dynamic_noDecay/dynamic_PN_km1000'))
print("Dynamic PN 2000")
display(plotting_utils.show_stopwatch(scratch_folder + 'dynamic_noDecay/dynamic_PN_km2000'))
# Out:
# Global
# Zonal square
# Zonal hex
# Dynamic FD
# Dynamic CN 500
# Dynamic CN 1000
# Dynamic CN 2000
# Dynamic PN 500
# Dynamic PN 1000
# Dynamic PN 2000

# %%
predictions_evaluations.plot_actual_vs_fitted_waitTime(data_global, iteration=50)
# Out:
#      count      mean        std        min       25%       50%       75%  \
# 0  16848.0 -0.475498  12.456972 -10.068693 -7.418693 -4.068693  2.285473
#
#          max         MSE       RMSE       MAE
# 0  191.36464  155.393036  12.465674  7.569322

# %%
predictions_evaluations.plot_actual_vs_fitted_waitTime(data_zonal_square, iteration=50)
predictions_evaluations.plot_actual_vs_fitted_waitTime(data_zonal_hex, iteration=50)
# Out:
#      count      mean       std        min       25%       50%       75%  \
# 0  20512.0  0.316244  5.188112 -28.080952 -2.216341 -0.185212  2.441954
#
#          max        MSE      RMSE       MAE
# 0  85.267708  27.015203  5.197615  3.356532
#      count      mean       std        min      25%       50%       75%  \
# 0  19268.0 -0.758343  5.298323 -29.558333 -3.16077 -0.910548  1.505809
#
#           max        MSE      RMSE       MAE
# 0  103.024941  28.645852  5.352182  3.483539

# %%
predictions_evaluations.plot_actual_vs_fitted_waitTime(data_dynamic_FD, iteration=50)
# Out:
#      count      mean       std        min       25%       50%       75%  \
# 0  19122.0 -0.301874  5.827535 -27.409631 -2.716861 -0.679554  1.785233
#
#           max        MSE      RMSE       MAE
# 0  124.913036  34.049522  5.835197  3.423956

# %%
predictions_evaluations.plot_actual_vs_fitted_waitTime(data_dynamic_CN_k500, iteration=50)
predictions_evaluations.plot_actual_vs_fitted_waitTime(data_dynamic_CN_k1000, iteration=50)
predictions_evaluations.plot_actual_vs_fitted_waitTime(data_dynamic_CN_k2000, iteration=50)
# Out:
#      count     mean       std      min      25%      50%       75%       max  \
# 0  18796.0 -0.92279  6.226392 -23.3593 -3.56025 -1.20215  1.411708  198.4275
#
#          MSE      RMSE      MAE
# 0  39.617437  6.294238  3.79901
#      count      mean        std        min       25%       50%       75%  \
# 0  18295.0 -0.287192  12.265001 -19.286883 -3.844742 -1.373817  1.426542
#
#           max         MSE       RMSE       MAE
# 0  386.674517  150.504502  12.268028  4.433366
#      count      mean      std        min       25%      50%       75%  \
# 0  16411.0 -2.132051  6.75444 -20.902742 -5.856438 -2.61025  0.303275
#
#           max        MSE      RMSE       MAE
# 0  106.317883  50.165324  7.082748  4.875884

# %%
predictions_evaluations.plot_actual_vs_fitted_waitTime(data_dynamic_PN_km500, iteration=50)
predictions_evaluations.plot_actual_vs_fitted_waitTime(data_dynamic_PN_km1000, iteration=50)
predictions_evaluations.plot_actual_vs_fitted_waitTime(data_dynamic_PN_km2000, iteration=50)
# Out:
#      count      mean      std        min       25%    50%       75%       max  \
# 0  19963.0 -0.025877  6.38711 -22.531833 -2.907467 -0.679  2.111767  189.3067
#
#          MSE      RMSE       MAE
# 0  40.793796  6.387002  3.687358
#      count      mean       std       min       25%       50%       75%  \
# 0  20257.0 -0.609844  4.729894 -18.43303 -3.117056 -0.935469  1.621458
#
#          max        MSE      RMSE      MAE
# 0  68.043429  22.742707  4.768931  3.31076
#      count      mean       std        min       25%       50%       75%  \
# 0  19171.0  1.595096  9.261909 -26.712254 -2.872825 -0.145488  4.303318
#
#           max       MSE      RMSE       MAE
# 0  126.554056  88.32282  9.398022  5.353847

# %%
predictions_evaluations.plot_actual_vs_fitted_travelTime(data_global, iteration=50)
# Out:
#      count      mean       std        min       25%       50%       75%  \
# 0  16848.0 -3.200798  8.411163 -87.272401 -5.629838 -2.647644 -1.132354
#
#           max        MSE      RMSE      MAE
# 0  156.624231  80.988576  8.999365  5.41198

# %%
predictions_evaluations.plot_actual_vs_fitted_travelTime(data_zonal_square, iteration=50)
# Out:
#      count      mean       std        min       25%      50%       75%  \
# 0  20512.0 -2.976005  6.815434 -78.522486 -4.253526 -1.97842 -0.814134
#
#           max        MSE      RMSE       MAE
# 0  108.646996  55.304485  7.436699  4.452917

# %%
predictions_evaluations.plot_actual_vs_fitted_travelTime(data_dynamic_CN_k1000, iteration=50)
# Out:
#      count      mean       std        min       25%      50%       75%  \
# 0  18295.0 -3.061253  8.043625 -71.925833 -4.703517 -2.18201 -0.913528
#
#           max       MSE      RMSE       MAE
# 0  152.847983  74.06764  8.606256  4.875083

# %%
predictions_evaluations.plot_actual_vs_fitted_travelTime(data_dynamic_FD, iteration=50)
# Out:
#      count      mean       std        min       25%       50%       75%  \
# 0  19122.0 -2.641316  8.394177 -62.832639 -4.258349 -2.056861 -0.826778
#
#           max        MSE     RMSE       MAE
# 0  341.131517  77.435072  8.79972  4.585598
