# %%
import pandas as pd
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', 500)
import seaborn as sns
import numpy as np
import matplotlib

# %%
import importlib
import plotting_utils
import utils
import euler_utils
import predictions_evaluations
importlib.reload(plotting_utils)
importlib.reload(utils)
importlib.reload(euler_utils)
importlib.reload(predictions_evaluations)
# Out:
# /cluster/apps/nss/gcc-6.3.0/python/3.8.5/x86_64/lib64/python3.8/site-packages/pyproj/__init__.py:78: UserWarning: Valid PROJ data directory not found. Either set the path using the environmental variable PROJ_LIB or with `pyproj.datadir.set_data_dir`.
#   warnings.warn(str(err))
# <module 'predictions_evaluations' from '/cluster/home/mfrancesc/IVT/eqasim-java/switzerland/Analysis_notebooks/predictions_evaluations.py'>

# %%
scratch_folder = '/cluster/scratch/mfrancesc/IVT/SA_scenario/'
work_folder = '/cluster/work/ivt_vpl/mfrancesc/SA_scenario/'

# %%
last_iter = 60

# %%
data_global = euler_utils.read_output(work_folder + 'global_average', last_iter=last_iter)
# Out:
# 100%|██████████| 61/61 [00:45<00:00,  1.34it/s]

# %%
data_zonal_square = euler_utils.read_output(work_folder + 'zonal_square', last_iter=last_iter)
data_zonal_hex = euler_utils.read_output(work_folder + 'zonal_hex', last_iter=last_iter)
# Out:
# 100%|██████████| 61/61 [00:56<00:00,  1.09it/s]
# 100%|██████████| 61/61 [00:53<00:00,  1.13it/s]

# %%
data_zonal_TAZ = euler_utils.read_output(work_folder + 'zonal_TAZ', last_iter=last_iter)
# Out:
# 100%|██████████| 61/61 [00:53<00:00,  1.15it/s]

# %%
data_dynamic_FD = euler_utils.read_output(work_folder + 'dynamic_FD_expDecay', last_iter=last_iter)
# Out:
# 100%|██████████| 61/61 [00:52<00:00,  1.17it/s]

# %%
data_dynamic_CN_k500 = euler_utils.read_output(work_folder + 'dynamic_CN_k500_expDecay', last_iter=last_iter)
data_dynamic_CN_k1000 = euler_utils.read_output(work_folder + 'dynamic_CN_k1000_expDecay', last_iter=last_iter)
data_dynamic_CN_k2000 = euler_utils.read_output(work_folder + 'dynamic_CN_k2000_expDecay', last_iter=last_iter)
# Out:
# 100%|██████████| 61/61 [00:54<00:00,  1.12it/s]
# 100%|██████████| 61/61 [00:55<00:00,  1.10it/s]
# 100%|██████████| 61/61 [00:54<00:00,  1.12it/s]

# %%
data_dynamic_PN_km500 = euler_utils.read_output(work_folder + 'dynamic_PN_km500_expDecay', last_iter=last_iter)
data_dynamic_PN_km1000 = euler_utils.read_output(work_folder + 'dynamic_PN_km1000_expDecay', last_iter=last_iter)
data_dynamic_PN_km2000 = euler_utils.read_output(work_folder + 'dynamic_PN_km2000_expDecay', last_iter=last_iter)
# Out:
# 100%|██████████| 61/61 [00:53<00:00,  1.13it/s]
# 100%|██████████| 61/61 [00:52<00:00,  1.16it/s]
# 100%|██████████| 61/61 [00:52<00:00,  1.17it/s]

# %%
last_iter=60

# %%
last_iter_dict = {
    'Global': data_global['drt_trips_stats'][last_iter],
    'Zonal square': data_zonal_square['drt_trips_stats'][last_iter],
    'Zonal hex': data_zonal_hex['drt_trips_stats'][last_iter],
    'Zonal TAZ': data_zonal_TAZ['drt_trips_stats'][last_iter],
    'Dynamic FD': data_dynamic_FD['drt_trips_stats'][last_iter],
    'Dynamic CN k=500': data_dynamic_CN_k500['drt_trips_stats'][last_iter],
    'Dynamic CN k=1000': data_dynamic_CN_k1000['drt_trips_stats'][last_iter],
    'Dynamic CN k=2000': data_dynamic_CN_k2000['drt_trips_stats'][last_iter],
    'Dynamic PN km=500': data_dynamic_PN_km500['drt_trips_stats'][last_iter],
    'Dynamic PN km=1000': data_dynamic_PN_km1000['drt_trips_stats'][last_iter],
    'Dynamic PN km=2000': data_dynamic_PN_km2000['drt_trips_stats'][last_iter]
}

# %%
display(plotting_utils.get_multiple_stats_table(last_iter_dict))
# Out:
#                                                         Global   Zonal square  \
# Number of rides                                  164211.000000  200200.000000
# Wait time (min)                   Mean                9.668589       7.077734
#                                   Median              6.550000       5.466667
#                                   Std                10.233444       6.816446
#                                   75-percentile      13.250000      10.066667
#                                   99-percentile      48.315000      27.450333
#                                   Max               158.966667     215.150000
# Travel time (min)                 Mean               13.162195      12.225600
#                                   Median              7.616667       7.450000
#                                   Std                15.633821      14.047276
#                                   75-percentile      16.433333      15.400000
#                                   99-percentile      78.216667      68.766833
#                                   Max               232.366667     306.066667
# Mean direct distance (km)                             2.600052       2.628481
# Average detour factor (time wise)                     1.654527       1.591387
#
#                                                      Zonal hex      Zonal TAZ  \
# Number of rides                                  198890.000000  199346.000000
# Wait time (min)                   Mean                6.745871       9.675450
#                                   Median              5.350000       6.233333
#                                   Std                 6.046473      20.828253
#                                   75-percentile       9.483333      11.450000
#                                   99-percentile      26.066667      59.866667
#                                   Max               150.716667     458.150000
# Travel time (min)                 Mean               12.215317      13.359406
#                                   Median              7.416667       7.466667
#                                   Std                13.725949      20.880633
#                                   75-percentile      15.450000      15.783333
#                                   99-percentile      67.233333      82.216667
#                                   Max               215.333333     470.950000
# Mean direct distance (km)                             2.638055       2.599171
# Average detour factor (time wise)                     1.570928       1.721139
#
#                                                     Dynamic FD  \
# Number of rides                                  196214.000000
# Wait time (min)                   Mean                6.727037
#                                   Median              5.300000
#                                   Std                 7.197292
#                                   75-percentile       9.216667
#                                   99-percentile      27.066667
#                                   Max               268.900000
# Travel time (min)                 Mean               12.293951
#                                   Median              7.383333
#                                   Std                14.396912
#                                   75-percentile      15.350000
#                                   99-percentile      69.350000
#                                   Max               263.250000
# Mean direct distance (km)                             2.617571
# Average detour factor (time wise)                     1.582263
#
#                                                  Dynamic CN k=500  \
# Number of rides                                     200746.000000
# Wait time (min)                   Mean                   7.103435
#                                   Median                 5.683333
#                                   Std                    6.633537
#                                   75-percentile          9.962500
#                                   99-percentile         27.283333
#                                   Max                  197.483333
# Travel time (min)                 Mean                  12.168257
#                                   Median                 7.416667
#                                   Std                   13.862405
#                                   75-percentile         15.350000
#                                   99-percentile         67.575833
#                                   Max                  257.133333
# Mean direct distance (km)                                2.634383
# Average detour factor (time wise)                        1.578993
#
#                                                  Dynamic CN k=1000  \
# Number of rides                                      195438.000000
# Wait time (min)                   Mean                    7.405893
#                                   Median                  5.900000
#                                   Std                     7.236705
#                                   75-percentile          10.316667
#                                   99-percentile          30.550000
#                                   Max                   257.166667
# Travel time (min)                 Mean                   12.388485
#                                   Median                  7.450000
#                                   Std                    14.364903
#                                   75-percentile          15.550000
#                                   99-percentile          70.483333
#                                   Max                   254.183333
# Mean direct distance (km)                                 2.626783
# Average detour factor (time wise)                         1.587727
#
#                                                  Dynamic CN k=2000  \
# Number of rides                                      198162.000000
# Wait time (min)                   Mean                    7.024898
#                                   Median                  5.566667
#                                   Std                     6.291745
#                                   75-percentile           9.950000
#                                   99-percentile          26.116667
#                                   Max                   184.750000
# Travel time (min)                 Mean                   12.221453
#                                   Median                  7.433333
#                                   Std                    13.829501
#                                   75-percentile          15.466667
#                                   99-percentile          66.766667
#                                   Max                   233.216667
# Mean direct distance (km)                                 2.644912
# Average detour factor (time wise)                         1.576620
#
#                                                  Dynamic PN km=500  \
# Number of rides                                      198668.000000
# Wait time (min)                   Mean                    7.119093
#                                   Median                  5.716667
#                                   Std                     6.163587
#                                   75-percentile          10.133333
#                                   99-percentile          28.472167
#                                   Max                   140.950000
# Travel time (min)                 Mean                   12.142836
#                                   Median                  7.383333
#                                   Std                    13.656073
#                                   75-percentile          15.300000
#                                   99-percentile          67.150000
#                                   Max                   234.666667
# Mean direct distance (km)                                 2.610581
# Average detour factor (time wise)                         1.579295
#
#                                                  Dynamic PN km=1000  \
# Number of rides                                       196148.000000
# Wait time (min)                   Mean                     7.427064
#                                   Median                   5.883333
#                                   Std                      7.266129
#                                   75-percentile           10.283333
#                                   99-percentile           35.266667
#                                   Max                    240.783333
# Travel time (min)                 Mean                    12.663795
#                                   Median                   7.433333
#                                   Std                     15.589264
#                                   75-percentile           15.450000
#                                   99-percentile           77.792167
#                                   Max                    332.900000
# Mean direct distance (km)                                  2.642120
# Average detour factor (time wise)                          1.605005
#
#                                                  Dynamic PN km=2000
# Number of rides                                       196064.000000
# Wait time (min)                   Mean                     7.344946
#                                   Median                   5.883333
#                                   Std                      7.413884
#                                   75-percentile           10.050000
#                                   99-percentile           34.222833
#                                   Max                    286.066667
# Travel time (min)                 Mean                    12.686664
#                                   Median                   7.383333
#                                   Std                     15.696026
#                                   75-percentile           15.400000
#                                   99-percentile           78.722833
#                                   Max                    290.850000
# Mean direct distance (km)                                  2.634653
# Average detour factor (time wise)                          1.601598

# %%
print("Global")
display(plotting_utils.show_stopwatch(work_folder + 'global_average'))
print("Zonal square")
display(plotting_utils.show_stopwatch(work_folder + 'zonal_square'))
print("Zonal hex")
display(plotting_utils.show_stopwatch(work_folder + 'zonal_hex'))
print("Zonal TAZ")
display(plotting_utils.show_stopwatch(work_folder + 'zonal_TAZ'))
print("Dynamic FD")
display(plotting_utils.show_stopwatch(work_folder + 'dynamic_FD_expDecay'))
print("Dynamic CN 500")
display(plotting_utils.show_stopwatch(work_folder + 'dynamic_CN_k500_expDecay'))
print("Dynamic CN 1000")
display(plotting_utils.show_stopwatch(work_folder + 'dynamic_CN_k1000_expDecay'))
print("Dynamic CN 2000")
display(plotting_utils.show_stopwatch(work_folder + 'dynamic_CN_k2000_expDecay'))
print("Dynamic PN 500")
display(plotting_utils.show_stopwatch(work_folder + 'dynamic_PN_km500_expDecay'))
print("Dynamic PN 1000")
display(plotting_utils.show_stopwatch(work_folder + 'dynamic_PN_km1000_expDecay'))
print("Dynamic PN 2000")
display(plotting_utils.show_stopwatch(work_folder + 'dynamic_PN_km2000_expDecay'))
# Out:
# Global
# Zonal square
# Zonal hex
# Zonal TAZ
# Dynamic FD
# Dynamic CN 500
# Dynamic CN 1000
# Dynamic CN 2000
# Dynamic PN 500
# Dynamic PN 1000
# Dynamic PN 2000

# %%
plot_list = [
    ('Global', data_global, last_iter),
    ('Zonal square', data_zonal_square, last_iter),
    ('Zonal hex', data_zonal_hex, last_iter),
    ('Zonal TAZ', data_zonal_TAZ, last_iter),
    ('Dynamic FD', data_dynamic_FD, last_iter),
    ('Dynamic CN k=500', data_dynamic_CN_k500, last_iter),
    ('Dynamic CN k=1000', data_dynamic_CN_k1000, last_iter),
    ('Dynamic CN k=2000', data_dynamic_CN_k2000, last_iter),
    ('Dynamic PN km=500', data_dynamic_PN_km500, last_iter),
    ('Dynamic PN km=1000', data_dynamic_PN_km1000, last_iter),
    ('Dynamic PN km=2000', data_dynamic_PN_km2000, last_iter)
]

# %%
plotting_utils.plot_bar_total_execution_time(plot_list)

# %%
waitTime_pred_stats = predictions_evaluations.plot_multiple_actual_vs_fitted(plot_list, 'waitTime')
# Out:
#                                       count      mean        std        min  \
# title
# Global on iteration 60              18381.0  0.547526  10.387095  -9.152282
# Zonal square on iteration 60        19350.0 -0.433363   5.791671 -27.849713
# Zonal hex on iteration 60           20449.0 -0.256258   5.157804 -35.047475
# Zonal TAZ on iteration 60           20347.0  3.197358  21.398727 -31.850000
# Dynamic FD on iteration 60          20516.0  0.030049   6.429944 -25.418804
# Dynamic CN k=500 on iteration 60    21663.0  0.629206   5.514503 -22.467433
# Dynamic CN k=1000 on iteration 60   20125.0  0.142123   5.844312 -23.944317
# Dynamic CN k=2000 on iteration 60   20990.0  0.212775   5.360927 -22.489160
# Dynamic PN km=500 on iteration 60   19677.0 -0.319380   5.134849 -25.052956
# Dynamic PN km=1000 on iteration 60  17878.0 -0.984661   5.670984 -31.258047
# Dynamic PN km=2000 on iteration 60  18296.0 -0.801720   5.728055 -37.268859
#
#                                          25%       50%       75%        95%  \
# title
# Global on iteration 60             -6.502282 -2.518948  4.047718  18.864385
# Zonal square on iteration 60       -2.755117 -0.619364  1.773698   6.592181
# Zonal hex on iteration 60          -2.564646 -0.594697  1.787059   6.308183
# Zonal TAZ on iteration 60          -1.918593  0.380952  3.879167  12.875222
# Dynamic FD on iteration 60         -2.388146 -0.403436  2.023859   6.757671
# Dynamic CN k=500 on iteration 60   -2.035910  0.031665  2.704851   7.737033
# Dynamic CN k=1000 on iteration 60  -2.347950 -0.358961  2.150499   6.994260
# Dynamic CN k=2000 on iteration 60  -2.377919 -0.378652  2.291380   7.567534
# Dynamic PN km=500 on iteration 60  -2.529187 -0.654256  1.604281   6.128991
# Dynamic PN km=1000 on iteration 60 -3.056976 -0.916260  1.370168   5.787354
# Dynamic PN km=2000 on iteration 60 -3.062033 -0.920709  1.335629   6.017702
#
#                                           99%         max         MSE  \
# title
# Global on iteration 60              40.071052  107.897718  108.185660
# Zonal square on iteration 60        13.960081  151.216954   33.729528
# Zonal hex on iteration 60           14.484795  100.375158   26.667314
# Zonal TAZ on iteration 60           55.266786  441.550000  468.106118
# Dynamic FD on iteration 60          17.847449  232.099784   41.343070
# Dynamic CN k=500 on iteration 60    17.024015  154.254394   30.804237
# Dynamic CN k=1000 on iteration 60   16.707402  213.636154   34.174483
# Dynamic CN k=2000 on iteration 60   15.884696  150.345880   28.783443
# Dynamic PN km=500 on iteration 60   16.322924   99.843208   26.467334
# Dynamic PN km=1000 on iteration 60  13.144625  133.341504   33.127818
# Dynamic PN km=2000 on iteration 60  16.967159  121.925439   33.451580
#
#                                          RMSE       MAE  % errors < 0
# title
# Global on iteration 60              10.401234  7.074573     61.378597
# Zonal square on iteration 60         5.807713  3.475979     57.602067
# Zonal hex on iteration 60            5.164040  3.230420     57.313316
# Zonal TAZ on iteration 60           21.635760  6.005614     45.726643
# Dynamic FD on iteration 60           6.429858  3.403123     54.898616
# Dynamic CN k=500 on iteration 60     5.550157  3.317233     49.591469
# Dynamic CN k=1000 on iteration 60    5.845895  3.316437     54.250932
# Dynamic CN k=2000 on iteration 60    5.365020  3.335914     54.263935
# Dynamic PN km=500 on iteration 60    5.144641  3.179347     58.662398
# Dynamic PN km=1000 on iteration 60   5.755677  3.572192     61.539322
# Dynamic PN km=2000 on iteration 60   5.783734  3.537753     61.543507

# %%
zonal_list = [
    ('Global', data_global, last_iter),
    ('Zonal square', data_zonal_square, last_iter),
    ('Zonal hex', data_zonal_hex, last_iter),
    ('Zonal TAZ', data_zonal_TAZ, last_iter)
]
dynamic_list = [
    ('Global', data_global, last_iter),
    ('Dynamic CN k=500', data_dynamic_CN_k500, last_iter),
    ('Dynamic CN k=1000', data_dynamic_CN_k1000, last_iter),
    ('Dynamic CN k=2000', data_dynamic_CN_k2000, last_iter),
    ('Dynamic PN km=500', data_dynamic_PN_km500, last_iter),
    ('Dynamic PN km=1000', data_dynamic_PN_km1000, last_iter),
    ('Dynamic PN km=2000', data_dynamic_PN_km2000, last_iter)
]

# %%
navy_hex = matplotlib.colors.to_hex('navy')
red_hex = matplotlib.colors.to_hex('darkred')
c_gradient = utils.get_color_gradient(red_hex, navy_hex, 4)
select_list = [
    ('Global', data_global, c_gradient[0], '-'),
    ('Zonal TAZ', data_zonal_TAZ, c_gradient[1], '--'),
    ('Dynamic CN k=1000', data_dynamic_CN_k1000, c_gradient[2], ':'),
    ('Dynamic PN km=1000', data_dynamic_PN_km1000, c_gradient[3], '-.')
]

# %%
predictions_evaluations.plot_iteration_avg_wait_time(select_list)

# %%
predictions_evaluations.plot_iteration_avg_wait_time(select_list, predictions=True)

# %%
travelTime_pred_stats = predictions_evaluations.plot_multiple_actual_vs_fitted(plot_list, 'travelTime')
# Out:
#                                       count      mean        std         min  \
# title
# Global on iteration 60              18381.0 -2.831623   7.338101  -73.059914
# Zonal square on iteration 60        19350.0 -2.979234   7.502416  -77.581394
# Zonal hex on iteration 60           20449.0 -2.777996   6.689876  -82.865762
# Zonal TAZ on iteration 60           20347.0 -2.236213  15.789516 -105.856832
# Dynamic FD on iteration 60          20516.0 -3.102368   7.084258  -81.904329
# Dynamic CN k=500 on iteration 60    21663.0 -2.752399   6.901959  -83.573566
# Dynamic CN k=1000 on iteration 60   20125.0 -2.880006   7.354398  -84.397238
# Dynamic CN k=2000 on iteration 60   20990.0 -2.715001   6.947221  -78.927539
# Dynamic PN km=500 on iteration 60   19677.0 -3.086897   6.632735  -83.425061
# Dynamic PN km=1000 on iteration 60  17878.0 -2.857648   7.734770  -70.805352
# Dynamic PN km=2000 on iteration 60  18296.0 -2.780761   7.708997  -69.965533
#
#                                          25%       50%       75%       95%  \
# title
# Global on iteration 60             -5.203285 -2.463506 -1.037176  6.465144
# Zonal square on iteration 60       -4.369992 -2.111250 -0.854963  4.011684
# Zonal hex on iteration 60          -4.115475 -1.962828 -0.773954  4.024143
# Zonal TAZ on iteration 60          -4.565412 -2.095735 -0.811626  6.166383
# Dynamic FD on iteration 60         -4.432394 -2.082181 -0.857424  3.560053
# Dynamic CN k=500 on iteration 60   -4.085248 -1.928147 -0.781904  4.248594
# Dynamic CN k=1000 on iteration 60  -4.302626 -1.989879 -0.798997  4.331845
# Dynamic CN k=2000 on iteration 60  -4.107104 -1.943814 -0.775953  4.411185
# Dynamic PN km=500 on iteration 60  -4.378548 -2.112308 -0.869483  3.727516
# Dynamic PN km=1000 on iteration 60 -4.550359 -2.223634 -0.926846  4.397919
# Dynamic PN km=2000 on iteration 60 -4.445587 -2.218456 -0.911665  4.432992
#
#                                           99%         max         MSE  \
# title
# Global on iteration 60              22.840458  128.972025   61.862882
# Zonal square on iteration 60        14.005374  225.784756   65.159174
# Zonal hex on iteration 60           14.219418  127.941992   52.469506
# Zonal TAZ on iteration 60           28.570293  359.394592  254.297200
# Dynamic FD on iteration 60          13.066307  144.262496   59.808946
# Dynamic CN k=500 on iteration 60    14.018560  151.485846   55.210546
# Dynamic CN k=1000 on iteration 60   15.612269  118.580429   62.378909
# Dynamic CN k=2000 on iteration 60   14.784486  104.666204   55.632810
# Dynamic PN km=500 on iteration 60   12.280500   95.317596   53.519871
# Dynamic PN km=1000 on iteration 60  21.733531  126.563812   67.989467
# Dynamic PN km=2000 on iteration 60  20.208479  158.757682   67.158026
#
#                                          RMSE       MAE  % errors < 0
# title
# Global on iteration 60               7.865296  4.974805     84.946412
# Zonal square on iteration 60         8.072123  4.545324     84.268734
# Zonal hex on iteration 60            7.243584  4.261069     83.422172
# Zonal TAZ on iteration 60           15.946699  5.835610     83.044183
# Dynamic FD on iteration 60           7.733624  4.477566     85.021447
# Dynamic CN k=500 on iteration 60     7.430380  4.296940     83.483359
# Dynamic CN k=1000 on iteration 60    7.898032  4.531079     83.567702
# Dynamic CN k=2000 on iteration 60    7.458740  4.341845     83.358742
# Dynamic PN km=500 on iteration 60    7.315728  4.414492     84.199827
# Dynamic PN km=1000 on iteration 60   8.245573  4.729465     84.679494
# Dynamic PN km=2000 on iteration 60   8.195000  4.650823     84.668780
